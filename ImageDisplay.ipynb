# %%
HW1 Image Display
Name: 최 혜주
Student Number: 202015052

# %%
from scipy.misc import imread, imsave, imresize
import matplotlib.pyplot as plt
import numpy as np

# %%
img=imread('./fourth_wave.png')
img=imresize(img,(800,1080))
img_tinted=img*[1,0.8,0.8]

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(np.uint8(img_tinted))
